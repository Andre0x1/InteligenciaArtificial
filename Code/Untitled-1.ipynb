# %%
import pandas as pd

DevImpact = pd.read_csv("C:/Users/Andre Silva/Desktop/Projetos_Git/PUC/InteligenciaArtificial/Code/devImpactDataSet.csv") 
DevImpact.describe()
# Out:
#                 Timestamp Questão 1 - Você trabalha como:  \
# count                 413                             413
# unique                413                              27
# top     4/7/2020 07:52:43    Desenvolvedor ou equivalente
# freq                    1                             310
#
#        Questão 2 - Qual a sua idade?  \
# count                            413
# unique                             4
# top                 menos de 30 anos
# freq                             199
#
#        Questão 3 - Quanto tempo você tem de experiência profissional?  \
# count                                                 413
# unique                                                  4
# top                                       mais de 10 anos
# freq                                                  188
#
#               Questão 4 - Você trabalha com?  \
# count                                    413
# unique                                    26
# ...
